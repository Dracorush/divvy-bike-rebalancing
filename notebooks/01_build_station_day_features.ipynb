# %% [markdown]
# Build station-day flow features from the cleaned Divvy parquet dataset.

# %%
import sys
from pathlib import Path

sys.path.append(str(Path("..").resolve()))

# %% [markdown]
# Load the cleaned parquet dataset produced in the previous pipeline stage.

# %%
import pandas as pd

DATA_PATH = Path("../data/cleaned/divvy_clean.parquet")

df = pd.read_parquet(DATA_PATH)

print(df.shape)
df.head()
# Out:
# (3362086, 13)
#             ride_id  rideable_type              started_at  \
# 0  7569BC890583FCD7   classic_bike 2025-01-21 17:23:54.538
# 1  013609308856B7FC  electric_bike 2025-01-11 15:44:06.795
# 2  EACACD3CE0607C0D   classic_bike 2025-01-02 15:16:27.730
# 3  EAA2485BA64710D3   classic_bike 2025-01-23 08:49:05.814
# 4  7F8BE2471C7F746B  electric_bike 2025-01-16 08:38:32.338
#
#                  ended_at            start_station_name start_station_id  \
# 0 2025-01-21 17:37:52.015     Wacker Dr & Washington St     KA1503000072
# 1 2025-01-11 15:49:11.139   Halsted St & Wrightwood Ave     TA1309000061
# 2 2025-01-02 15:28:03.230  Southport Ave & Waveland Ave            13235
# 3 2025-01-23 08:52:40.047  Southport Ave & Waveland Ave            13235
# 4 2025-01-16 08:41:06.767  Southport Ave & Waveland Ave            13235
#
#             end_station_name end_station_id  start_lat  start_lng    end_lat  \
# ...

# %% [markdown]
# Import the feature engineering function that builds the station-day flow table.
#
# Apply the feature engineering pipeline to create one row per station per day.

# %%
from src.feature_engineering import build_station_day_flow_table

station_day_flows = build_station_day_flow_table(df)

print(station_day_flows.shape)
station_day_flows.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 3
#       1 from src.feature_engineering import build_station_day_flow_table
# ----> 3 station_day_flows = build_station_day_flow_table(df)
#       5 print(station_day_flows.shape)
#       6 station_day_flows.head()
#
# File ~/divvy_project/src/feature_engineering.py:147, in build_station_day_flow_table(df)
#     144 df = add_trip_date_column(df)
#     146 daily_flows = build_daily_flows(df)
# --> 147 station_day_calendar = build_station_day_calendar(df)
#     149 station_day_flows = station_day_calendar.merge(
#     150     daily_flows,
#     151     on=["station_id", "trip_date"],
#     152     how="left"
#     153 )
#     155 station_day_flows["trips_departed"] = station_day_flows["trips_departed"].fillna(0)
#
# File ~/divvy_project/src/feature_engineering.py:114, in build_station_day_calendar(df)
# ...

# %% [markdown]
# Check that departures and arrivals are present and that quiet days were filled with zeros.
